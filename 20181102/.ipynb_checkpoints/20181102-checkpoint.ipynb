# %%
class Point(object):
    """represents a point in 2-D space"""
print(Point)
blank = Point()
print(blank)

blank.x = 3.0
blank.y = 4.0
print(blank.x)
print(blank.y)
# Out:
# <class '__main__.Point'>
# ...
# 3.0
# 4.0

# %%
class Point(object):
    """represents a point in 2-D space"""
class Rectangle(object):
    """represent a rectangle.attributes: width, height, center."""

box = Rectangle()
box.width = 100.0
box.height = 200.0
box.center = Point()
box.center.X = 0.0
box.center.y = 0.0

def print_point(p):
    print('(%g, %g)' % (p.x, p.y))

#1
def get_center(box):
    p = Point()
    p.x = box.center.X
    p.y = box.center.y
    return p

center = get_center(box)
print_point(center)

#2
def get_area(box):
    a = box.width * box.height
    return a

area = get_area(box)
print(area)

#3
def perimeter(box):
    peri = (box.width + box.height)*2
    return peri

perimeter = perimeter(box)
print(perimeter)

#8
def flip_horizontal(box):
    p = Point()
    p.x = box.center.X - box.width
    p.y = box.center.y

#9
def flip_vertical(box):
    p = Point()
    p.x = box.center.X 
    p.y = box.center.y - box.height

#10
def mirror_x(box):
    p = Point()
    p.x = box.center.X 
    p.y = -box.center.y

#11
def mirror_y(box):
    p = Point()
    p.x = -box.center.X 
    p.y = box.center.y

#12
def rotate(box):
    w = box.width
    h = box.height
    box.height = w
    box.width = h

#13
def copy(box): 
    box_copy = Rectangle()
    box_copy.width = box.width
    box_copy.height = box.height
    box_copy.center = Point()
    box_copy.center.X = box.center.X
    box_copy.center.y = box.center.y
    return box_copy

#14-1
def move_1(box, x, y):
    p = Point()
    p.x = X 
    p.y = y
    
#14-2
def move_2(box, v, h):
    p = Point()
    p.x = X + v
    p.y = y + h
    
#15
def resize(w, h):
    box.width = w
    box.height = h
    
#16
def extent(box):
    xmin = box.center.X - box.width/2
    xmax = box.center.X + box.width/2
    ymin = box.center.y - box.height/2
    ymax = box.center.y + box.height/2
    return xmin, xmax, ymin, ymax
# Out:
# (0, 0)
# 20000.0
# 600.0
